# %% [markdown]
# # Jupyter Notebook

# %%
print('hello world')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0, 100, num=10000)
y = np.sin(x)
plt.figure()
plt.plot(x, y)
plt.show()
